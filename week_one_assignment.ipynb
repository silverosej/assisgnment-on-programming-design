# %%
name="John Chinaza"
print(name)
# Out:
# John Chinaza

# %%
num1=25
num2=10
addition=num1 + num2
print(addition)
# Out:
# 35

# %%
num1=25
num2=10
difference=num1 - num2
print(difference)
# Out:
# 15

# %%
num1=25
num2=10
product=num1 * num2
print(product)
# Out:
# 250

# %%
num1=25
num2=10
quotient=num1 / num2
print(quotient)
# Out:
# 2.5

# %%
price=2500
quantity=7
total_cost=price * quantity
total=total_cost
print(total)
# Out:
# 17500

# %%
length=15
width=9
area=length * width
print(area)
# Out:
# 135

# %%
math=78
chem=82
english=65
physics=90
geo=75
total_score=math + chem + english + physics + geo
print(total_score)

print(total_score/5)
# Out:
# 390
# 78.0

# %%
remainder=47%6
print(remainder)
# Out:
# 5

# %%
cal=5**4
result=cal
print(result)
# Out:
# 625

# %%
product_cost=8500
discount=20
discount_amount=(discount/100)*product_cost
print(discount_amount)
# Out:
# 1700.0

# %%
total_minutes=156
hours=total_minutes//60
remaining_minutes=total_minutes%60
print(hours,remaining_minutes)
# Out:
# 2 36

# %%
car_travel=240
hours=3
speed=car_travel/hours
print(speed)
# Out:
# 80.0
